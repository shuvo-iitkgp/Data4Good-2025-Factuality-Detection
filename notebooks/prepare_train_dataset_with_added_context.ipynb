# %%
import pandas as pd


train_org_df = pd.read_json("train.json")
train_org_df.query("context == '' ").shape[0]
# Out:
# 1869

# %%
added_context = pd.read_csv("/content/serpapi-trainset-NOCONTEXT.csv")

# %%
final_df = added_context[['answer', 'model_context']].merge(train_org_df, how= 'right', on = "answer")

# %%
train_org_df['context'] = final_df[['model_context', 'context']].bfill(axis=1).iloc[:, 0]

# %%
train_org_df.query("context == '' ")
# Out:
#                                                   answer     type context  \
# 5      The process that can increase solar energy pot...  factual
# 16     The Presbyterian church was established in Eng...  factual
# 39     The pupal stage is the developmental phase tha...  factual
# 52     Human psychology is part of the interdisciplin...  factual
# 56     The subtype of clitellates that includes earth...  factual
# ...                                                  ...      ...     ...
# 20933  The two publications, the 1998 Strategic Defen...  factual
# 20957  The French government believed that Jean-Claud...  factual
# 20982  Masjid Bilal is situated on Chimbarazoo Boulev...  factual
# 21005  The Taff Vale Case in 1901 boosted support for...  factual
# 21007  The building that houses the Edgar Allan Poe M...  factual
#
#                                                 question
# 5      What is the process called that can increase s...
# ...

# %%
train_org_df.to_json("train_updated.json", orient="records", indent=2)
